# %% [markdown]
# <a href="https://colab.research.google.com/github/VaneCamposGuzman/Cancer_Piel/blob/main/cancerpiel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Montamos Drive para que los pesos se guarden en tu nube en tiempo real
from google.colab import drive
drive.mount('/content/drive')

# 2. Instalamos la librería limpia de YOLO
# !pip install ultralytics
# Out:
# Mounted at /content/drive
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 31.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 2.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os

# Cargamos el modelo nano (el más rápido de todos para pruebas rápidas)
model = YOLO('yolov8n.pt')
print("Entorno y modelo base listos.")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Entorno y modelo base listos.

# %%
# Entrenamos con un dataset de prueba integrado (coco8) que tarda menos de 2 minutos
# !yolo task=detect mode=train model=yolov8n.pt data=coco8.yaml epochs=5 imgsz=640 project="/content/drive/MyDrive/Nuevo_Proyecto_YOLO" name="control_calidad"
# Out:
# Ultralytics 8.4.71 🚀 Python-3.12.13 torch-2.11.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...
